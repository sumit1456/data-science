# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder

# Dataset
weather = ['Sunny','Sunny','Overcast','Rainy','Rainy','Rainy',
           'Overcast','Sunny','Sunny','Rainy','Sunny','Overcast',
           'Overcast','Rainy']

temp = ['Hot','Hot','Hot','Mild','Cool','Cool','Cool','Mild',
        'Cool','Mild','Mild','Mild','Hot','Mild']

play = ['No','No','Yes','Yes','Yes','No','Yes','No',
        'Yes','Yes','Yes','Yes','Yes','No']

# Convert categorical data into numbers
weather_encoder = LabelEncoder()
temp_encoder = LabelEncoder()
play_encoder = LabelEncoder()

weather_encoded = weather_encoder.fit_transform(weather)
temp_encoded = temp_encoder.fit_transform(temp)
play_encoded = play_encoder.fit_transform(play)

# Input features
X = list(zip(weather_encoded, temp_encoded))
y = play_encoded

# Create Naive Bayes model
model = GaussianNB()

# Train the model
model.fit(X, y)

# Encode the new tuple [Overcast, Mild]
new_weather = weather_encoder.transform(['Overcast'])[0]
new_temp = temp_encoder.transform(['Mild'])[0]

new_data = [[new_weather, new_temp]]

# Predict
prediction = model.predict(new_data)

# Convert prediction back to Yes/No
result = play_encoder.inverse_transform(prediction)

print("Prediction:", result[0])
